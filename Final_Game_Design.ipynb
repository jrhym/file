# %% [markdown]
# <a href="https://colab.research.google.com/github/jrhym/file/blob/main/Final_Game_Design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title
def ship_abduction(): #ship abduction function/arc
  print(
      f'''
      You start to slowly come to. Your head is absolutely killing you and you’re still super hungry (it is lunchtime after all). 
      As your eyes begin to focus you take stock of everything around you. 
      This interior is definitely more chrome and streamlined than anything you’ve ever seen around Walnut Creek.
      {player_input}: 'Geezus, I don’t think I’m in Ohio anymore…'
      Whoever left you here forgot to strap you down on the table. You stand up and look around. 
      From a quick glance around, only a few things in the room really stand out to you.
      Under a clear glass dome you see THE MOST PERFECT CORN specimen you have ever seen in all your 19 years. 
      Truly this must be the pinnacle of all corn. It spins enticingly under the dome. 
      Your stomach is rumbling up a storm, hungry for corn. 
      But wait… your Pa did always say that were you to eat raw corn you would face dire consequences. 
      Will you eat the corn or ignore it?
      Enter 'E' to eat the corn.
      Enter 'I' to ignore the corn. 
      ''')
  while True:
    ship_choice_1=input()
    if ship_choice_1=='E' or ship_choice_1=='e':
      print(
        f'''
        You lift up the glass dome in reverence, your gaze dominated by the corn underneath. 
        You wrap your fingers around the yellow beauty. 
        The weight and shape of the corn in your hand is the most satisfying feeling you have ever experienced. 
        Truly this is the peak of all corns’ majesty. 
        As you finally sink your teeth into the succulent skin, you are almost overwhelmed by the intense flavor. 
        As if all dishes on earth were condensed into this one perfect vegetable. 
        Every bite sends shivers of pure pleasure down your spine, the juices dribbling down your chin. 
        Not only is your hunger satiated, you feel as if you shall never experience hunger again. 
        Nothing, NOTHING could ever compare to this corn for as long as you may live. 
        But . . .
        As you are partaking in your meal, an alien enters the room. 
        Alien: “Wait . . .  wait . . .”
        You finally look up and notice him. He has a look of horror on his face. 
        Alien: “Corn . . .  subject! Not food! Was man.”
        The alien speaks in broken English but you catch his meaning. 
        Your heart sinks as you look down to the remains of the corn. You gulp, afraid to speak.
        {player_input}: “Wh-who was this subject? D-did the man have a name?”
        Alien: “Name was Bo Billy Thornton. Wanted to be corn for day . . .”
        You barely register the alien’s words, though, your heart is already broken. 
          You collapse to your knees, still clutching the corn bone in your hand. 
            As you sob and wretch you tell the alien the horrid, ugly truth. 
              {player_input}: “Bo Billy . . . was my Pa.” 
                THE END
        ''')
    break
  if ship_choice_1=='I' or ship_choice_1=='i':
    print(
        '''
        You decide you will heed the wise words of your father. 
        You leave the corn in its little glass dome and look around some more. 
        You notice something else interesting a little to the left of the corn. 
        It appears to be an ink-soaked sponge with a stamper right beside it. 
        Examining the stamper more closely, it appears like the stamper will leave a 
        star-shaped mark on an object. 
        Honestly, you think a star-shaped mark will look pretty cute and charming when placed upon your hand…  
 		    Will you stamp your hand with the star mark? Yes or no?
        Enter 'Y' for Yes.
        Enter 'N' for No.
        ''')
    while True:
      ship_choice_2=input()
      if ship_choice_2=='N' or ship_choice_2=='n':
        print(
            f'''
            Just as you are finishing up your look-around, the alien walks back in. 
            He looks a little confused as to why you are not still on the table, but otherwise he seems nice enough. 
            Alien: 'You awake now! Good. I finish experiment soon. Can watch.' 
            The alien walks over to the covered corn, taking it out and placing it on a flat metal table. 
            He flips some switches and soon a bright purple beam shoots out at the cob.
            
            The light is too bright for you to properly see, but you think you see the corn sprouting limbs! 
            As the light dies down, you see your father laid out on the table. 
            He looks different now though. 
            Like the alien, his skin is now a soft, cornish yellow. 
            His fingernails are curled up like kernels. 
            His body is naked save for a corn husk loincloth covering up his pelvis. 
            His body is drenched in a non-descript oil and his eyes are shut tight. 
            Your father begins to stir; his eyes slowly creak open and he sits up on his arms, looking around and getting his bearings. 
            In a state of abject shock you exclaim, 'Pa? What the hell? What happened to you? Why were you corn?'
            
            Bo Billy: 'I saw a flying ship in the sky, next thing I knew I was in a ship with aliens. 
            So I figured I might as well ask this here alien if he can show me the truth about corn so I can better my farm. 
            Then he turned my ass into corn!'
            Exasperated, you let out a sigh, trying to wrap your head around the situation. 
            {player_input}: 'Okay then . . . You feel your stomach growl like a rabid dog. 
            {player_input}:'Well . . . it is lunchtime, Pa. Timmy made his world famous corn beef sloppy joes. 
            Do you want to head back and eat?'
            Your dad inhales sharply, building up strength, and lets out a grunt as he slumps off the table. 
            He stumbles over to you, and slaps his big, greasy arm over your shoulder like he always used to when you were younger. 
            Bo Billy: 'Yeah, son. Let’s go home.'
            ''')
        break
      if ship_choice_2=='Y' or ship_choice_2=='y':
        print(
            f'''
            Just as you are finishing your look-around, the alien walks back in. 
            He looks a little confused as to why you are not still on the table, but otherwise he seems nice enough. 
            Alien: 'Blimey! I didn’t realize you had woken up already. I’m just about to finish up this 
            experiment. It’ll be a jolly good show, please feel free to watch.' 
            
            The alien walks over to the covered corn, taking it out and placing it on a flat metal table. 
            He flips some switches and soon a bright purple beam shoots out at the cob.
            The light is too bright for you to properly see, but you think you see the corn sprouting limbs! 
            As the light dies down, you see your father laid out on the table. He looks different now though. 
            Like the alien, his skin is now a soft, cornish yellow. His fingernails are curled up like kernels. 
            His body is naked save for a corn husk loincloth covering up his pelvis. 
            His body is drenched in a nondescript oil and his eyes are shut tight. 
            Your father begins to stir; his eyes slowly creak open and he sits up on his arms, looking around and getting his bearings. 
            In a state of abject shot you exclaim, {player_input}: 'Pa? What the hell? What happened to you? Why 
            were you corn?'
            
            Bo Billy: 'I saw a flying ship in the sky, next thing I knew I was in a ship with aliens. 
            So I figured I might as well ask this here alien if he can show me the truth about corn so I can better my farm. 
            Then he turned my ass into corn!'
            The alien has been watching your whole exchange, a pleased smile on his face. 
            Alien: 'Yes, this bloke here begged me to make his dream come true. I just had to oblige.'
            Bo Billy: 'Ha ha ha! That silly alien and his broken words. I can just barely understand him.' 
            You give your father a perplexed look. 
            {player_input}: 'Really? I can understand him perfectfully. Sounds like one of those British fellers.'
            The alien’s face lights up.
            
            Alien: 'By the Queen! You can understand me?! Wait, give me your hand.' 
            The alien looks at the hand with the star mark. 
            Alien: 'The mark of the traveler! That means you’re one of us. 
            My boy, would you like to travel the stars with me?' 
            Your whole life you’ve been bred to be a corn farmer, but maybe it is time to try something new. 
            {player_input}: 'You know what . . . I reckon I will join you in your space adventures.' 
            Before you depart, you drop your Pa off back at the homestead, and give your brother a farewell hug. 
            You will miss your family, but your new life is about to begin. 
            You and the alien begin to leave the upper atmosphere.
            {player_input}: 'Okay buddy, let’s make some memories'
            Thus begins the adventures of {player_input} Thornton and the Alien!
            ''')
        break
      else:
        print("Sorry I didn't understand that. Answer the question with 'Y' or 'N' response.")
        continue

# %%
#@title
#This is the introduction

print(
    '''
    It’s a lovely afternoon in Walnut Creek, Ohio.
    You gaze out into your father’s cornfield.
    Its beautiful green and yellow majesty of it all is 
    almost too much for you to handle.
    
    Your eyes start to well up just a little.
    You distantly hear your older brother, 
    Timmy Thom Thornton, calling your name from atop his tractor.
    He is clad in his well-worn denim overalls and drenched in sweat from a long day of work.
    You hear Timmy call your name once more. What is your name?
    ''')

#User name entry code
while True:
  player_input=input()
  if player_input=="Tim" or player_input=="tim" or player_input=="Timmy" or player_input=="timmy":
    print("You dummy, that's your brother's name!")
    continue
  if player_input=="Bo" or player_input=="bo" or player_input=="Billy" or player_input=="billy":
    print("You bumbling buffoon! That's your Pa's name!")
    continue
  else:
    print("Gee Golly, what a great name!")
    break




#@title
#First user choice
print(
    f'''
    Timmy: '{player_input} Good to see your good-for-nothing self has finally woken up.
    It's almost lunchtime for corn's sake!'
    {player_input}: 'Sorry Tim! I were just to overwhlmed by the corn's beauty.'
    Timmy nods in understanding. 
    Timmy: 'Ay can relate to that there, brother! I guess you’re forgiven.' 
    The two of you briefly sing the praises of corn.
    ''')

print(
    f'''
    Timmy: 'Well, speaking of lunchtime, we ought to bring back Pa’. 
    He’s out deep in the fields right now. Do you reckon you could go fetch him for me {player_input}?'
    Will you do as Timmy requests? Answer Y or N.
    ''')
#User has no choice, will be forced to enter into cornfield
while True:
  response_1=input()
  if response_1=="N" or response_1=="n":
    print("But ya gotta! It's lunch time. Don't want him a'eating raw corn!")
    break
  if response_1=="Y" or response_1=="y":
    print(f"Thank you {player_input}! I think he should be in the center of the cornfield right now.")
    break
  else:
    print("Please answer Y or N for the story to continue.")
    continue


#@title
#Narrative branches, user chooses between three branches
print(
    '''
    You start heading towards the cornfield. 
    There are three different paths in front of you. 
    One leads to the left of the field, one towards the right, 
    while the largest path leads to the center. 
    Which path will you take? Please make your answer in the form of L for left
    , R for right, or C for center.
    '''
    )

while True:
  response_2=input()
  #Left branch = Clone Arch
  if response_2=="L" or response_2=="l":
    print(
        '''
        You head towards the path in the cornfield to the left. You hear Timmy in the distance grumble, “Ay don't know why ya wouldn't listen ta me . . .” 
        You find yourself on a straight path going downhill with short, infant corn on either side going up to your ankles. 
        You marvel at the young corn, dreaming of what it could one-day become. 
        As you walk briskly down the hill, you see someone down the path riding a tractor. “That must be Pa,” you think to yourself. 
        You feel your stomach screaming for food and break out into a sprint towards the man on the tractor, desperate to get your Pa and get lunch. 
        When you get a good view of the man on the tractor, you realize something is wrong–that’s not Pa! 
        It’s your brother, Timmy Thom Thornton! 
        How did he get all the way downhill when you just saw him back at the homestead? 
        Why is his skin completely dry and not drenched in sweat? Also, he is riding atop an old Ford 8n model tractor! 
        Why wouldn’t he be using the Fendt 211 Vario we got him for his birthday this year?
        ''')
    break
  #Right Branch = Cow Branch
  if response_2=="R" or response_2=="r":
    print(
        '''
        You start walking on the path in the cornfield branching to the right. 
        You hear Timmy in the distance grumble, “Ay don't know why ya wouldn't listen ta me . . .” 
        You find yourself on a winding path that leads far to the right of your farm, out of view. 
        The walls of corn around you are a medium height, just at eye level, but are majestic nonetheless. 
        As you walk and admire the perfectly medium-sized corn, you feel warm tears welling up in your eyes. 
        Some time passes on this path and you faintly hear a cow wailing coming from a direction down the path and high above–but, 
        wait a diddly-damn minute, cows can’t fly!
        ''')
    break
  #Center Branch = Ship Arch
  if response_2=="C" or response_2=="c":
    print(
        '''
        You start walking in the direction Timmy told you about. 
        The path is long and takes you deep (and I mean DEEP) into the cornfield. 
        The walls of corn are so high that they are more akin to skyscrapers than mere plants.
        You stop briefly to praise the majesty of corn.
        ''')
    break
  else:
    print("Sorry, I didn't understand that.Please make your answer in the form of L for left, R for right, or C for center.")
    continue



#@title
if response_2=="C" or response_2=="c": #Center branch/ship branch
  print("How many minutes do you praise the corn for? Only enter a numeral.")
  corn_praise=int(input())
 #Godly Hours
  print(f"You praise corn for {corn_praise} minutes.")
  print(
      '''
      That was a good spot of worship! 
      You start your journey to the center once again. 
      As you approach your destination, a chill descends on the field and you hear a faint mechanical humming in the air. 
      The path opens up and in front of you, you see a beautiful, sleek star cruiser. 
      Its shape is reminiscent of a boat of gravy. You are reminded of your hunger. 
      This ship could be dangerous, what will be your plan of action?
      Do you approach the ship, back away slowly or run away screaming (like a coward)?
      Please indicate your answer by inputing 'A' for 'approach', B for 'back away', or R for 'run away'.
      ''')

  while True:
    c_response_1=input()
    if c_response_1=="A" or c_response_1=="a":
    #Leads back to thed Ship Abduction Arch
      print(
          '''
          You approach the ship as cautiously as possible. 
          As you get nearer, however, the hatch on the ship opens up. 
          You are only slightly shocked to an alien, who is about your height, walks out. 
          His shiny skin is a beautiful pale yellow, reminiscent of the most majestic corn ever grown.
           You are so caught in your corn musings that you don’t notice how he dashes in front of you, takes out an alien-looking gun, and shoots you point-blank. 
           The world goes black and you know no more.
           ''') #come back and add stuff for ship abduction
      ship_abduction()
      break
    
    if c_response_1=="B" or c_response_1=="b":
    #User game play ends
      print(
          f'''
          You back away slowly from the ship, inching away until you are safely back in 
          the cover of the corn. When the ship is no longer in sight, you book it back to the 
          homestead, fear seizing your heart. You arrive back at the homestead, trying to rationalize what you saw. 
          {player_input}: “I were just hallucinating, that’s it! Ain’t no way a giant gravy boat is out there in the field. 
          I’m just really hungry. I’ll just wait here for Pa to return and we’ll have a good laugh about all this!
          You go back inside the house to wait. 
          And wait. 
                    And wait some more.
                                        But your father doesn’t come back, and you never see him again. 
                                                                                                        THE END
            ''') #Neutral ending for C_response_1
      break
    
    if c_response_1=="R"or c_response_1=="r":
    #This leads back to Ship Abduction
      print(
          '''
          You start to run away, a scream catching in your throat. 
          But the ground is slick with broken and discarded corn husks. 
          With a yelp, you slip to the ground, knocking your head against a rock. 
          As your vision starts to fade to black, you can almost swear that the figure that approaches you in the avatar of corn itself. 
          But your mind is too foggy to process that right now. 
          The world goes black around you and you know no more. 
          ''') #Ship abduction
      ship_abduction()
      break
    else:
      print("Sorry, I didn't understand that. Please indicate your answer by inputing 'A' for 'approach', B for 'back away', or R for 'run away'")
      continue



#@title
if response_2== "R" or response_2== "r": #Right Branch / Cow Branch
  print("Do you run towards the sound? Answer the question with 'Y' or 'N' response")
  while True: 
    r_response_1=input()
    if r_response_1=='Y'or r_response_1=='y':
      print("You’re in for a real licking from Pa if that cow eats any of your precious corn.")
      break
    if r_response_1=="N" or r_response_1=="n":
      print("Pa would be furious if you let the cow eat any of your precious corn! Muster any strength you can and go!")
      break
    else:
      print("It was a yes or no question you dummy. Do you approach the sound?")
      continue
  print(
      '''
      You break into a sprint through the maze of corn, fear mounting inside for the licking you will get if you don’t stop that cow. 
      The cow’s mooing grows louder and louder as you dart right and into a large opening in the field ahead. 
      You are now sure the noise is coming from above. 
      You reach the clearing and gasp. 
      You see a giant beam of light from the sky, coming down from well above the clouds. 
      In the middle of the beam, you see your favorite cow, Betsy, slowly being lifted higher into the air. 
      Betsy is kicking her legs frantically and mooing. 
      In a panic, you reach for your trusty lasso tied to your belt. 
      Pa said to only use it for emergencies. Do you attempt to lasso the cow? Or turn and run away?
      Type 'L' for lasso or 'R' for run away.
      ''')
  while True:
    r_response_2=input()
    if r_response_2=="L" or r_response_2== "l":
      #This leads back to Ship Abduction
      print(
          '''
          You run towards the beam of light with Betsy rising higher into the air. 
          You grip your lasso as you approach the screaming cow high above. 
          Wiping your sweaty brow you mutter, 
          'Corn help me.' 
          Without breaking stride, you reel your arm back with the lasso and whip it upward towards Betsy. 
          The brown rope shoots upward and slams against Betsy’s side, looping around her body twice. 
          You feel the rope pull taught and your feet being lifted off the ground as you begin rising with Betsy. 
          
          'What in Sam Hell?' You scream as the ground beneath you grows farther and farther away. 
          'Betsy, where are you taking us?' The air grows frigid and wet; 
          you pass through a cloud, drenching you in a chilly water. 
          Your breath becomes sparse in the thin air, you feel your chest pounding and lungs hyperventilating. 
          Your vision goes black.
          ''')#add stuff for ship abduction arc
      ship_abduction()
      break
    
    if r_response_2=="R" or r_response_2=="r":
     #User game play ends
      print(
          f'''
          You back away slowly from the beaming light and cow until you are safely back in the cover of the corn. 
          Once on the main path again, you turn your back to noise and run to your homestead, fear seizing your heart. 
          You arrive back at the homestead, trying to rationalize what you saw. 
          {player_input}: 'I were just hallucinating, that’s it! 
          Ain’t no way Betsy was flying through the sky being sucked into the heavens by a beam. 
          I’ll just wait here for Pa to return and we’ll have a good laugh about all this!' 
          You go back inside the house to wait. 
            And wait. 
              And wait some more. 
                The sun sets on the field of corn. 
                  But your father doesn’t come back, and you never see him again. 
                                                                                  THE END
          ''')
      break
    else:
      print("Sorry, I didn't understand that. Type 'L' for lasso or 'R' for run away.")
      continue



#@title
if response_2== "L" or response_2== "l": #Left Branch / Clone Branch
  print("Do you approach this mysterious ‘brother’ of yours? Answer the question with 'Y' or 'N' response")
  while True: 
    l_response_1=input()
    if l_response_1 == 'Y' or l_response_1 == 'y': 
    #This leads back to Ship Abduction
      print(
          '''
          You walk up towards the ancient tractor and the mysterious man that resembles your brother. 
          His eyes are a dull gray instead of their usual syrupy brown. 
          His hands are white from a brutal grip on the steering wheel, shaking with intensity. 
          You tentatively say, 
          'Hey Timmy . . . you feeling alright?' 
          Timmy does not react or look up from his tractor, the only response he gives is a strange, guttural grunt. 

          Your suspicion mounting, you decide to ask your brother a question that only he would know the answer to. 
          'Hey Timmy . . . you remember how I got that scar on my left thigh?' 
          Timmy’s face, shaking with intensity, slowly creaks towards you and meets your gaze with disturbing gray eyes. 
          As he spoke, it seemed the words took incredible effort for him to spit out.
          'A . . . blaster . . . shot . . . thigh' He finally croaked out. 
          A blaster? What the hell was this guy on about? 
          All you know is that this is certainly not your brother. 
          It must be an imposter (just like in Among Us!). 
          
          It is time to act. 
          
          You jump onto the tractor and cock your fist back, ready to pummel this fake brother to a pulp. 
          But as you jump up with one leg on the side of the tractor, ready to attack, the Fake Timmy shoots his arm out with lightning speed. 
          Before you can react, the man with gray eyes lands a devastating shot to your balls. 
          You feel the intense blast of pain attack your balls and move up your entire body. 
          You crumble and fall off the tractor, plummeting to the sweet corny earth. 
          Your eyes, now filled with tears, are seeing spots. 
          Your vision goes black. 
          ''')
      ship_abduction()
      break
  

    if l_response_1 == 'N' or l_response_1 == 'n':
      print(
          f'''
          You back away from the strange man who looks like your brother on the old tractor. 
          Once you are far back up the hill, away from the suspect individual, you break out into a run. 
          Something was not right about Timmy. 

          Panting, you arrive back at the homestead. 
          You slam open the door and check the kitchen, check the upstairs, but Timmy is nowhere to be found. 
          {player_input}: 'I were just hallucinating, that’s it! 
          Ain’t no way Timmy was out there! 
          I’m just really hungry. I’ll just wait here for Pa to return and we’ll have a good laugh about all this!'
          You go back inside the house to wait. 
            And wait. 
             And wait some more. The sun set on the cornfield. 
              But your father doesn’t come back, and you never see him again. 
                THE END
          ''')
      break
    else:
      print("Sorry I didn't understand that. Answer the question with 'Y' or 'N' response.")
# Out:
#     It’s a lovely afternoon in Walnut Creek, Ohio.
#     You gaze out into your father’s cornfield.
#     Its beautiful green and yellow majesty of it all is
#     almost too much for you to handle.
#
#     Your eyes start to well up just a little.
#     You distantly hear your older brother,
#     Timmy Thom Thornton, calling your name from atop his tractor.
#     He is clad in his well-worn denim overalls and drenched in sweat from a long day of work.
#     You hear Timmy call your name once more. What is your name?
#
# poop
# Gee Golly, what a great name!
#
#     Timmy: 'poop Good to see your good-for-nothing self has finally woken up.
#     It's almost lunchtime for corn's sake!'
#     poop: 'Sorry Tim! I were just to overwhlmed by the corn's beauty.'
#     Timmy nods in understanding.
#     Timmy: 'Ay can relate to that there, brother! I guess you’re forgiven.'
#     The two of you briefly sing the praises of corn.
#
#
# ...
